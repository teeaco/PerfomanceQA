# %% [markdown]
# **2.1.1 Введение в СУБД**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **2.1.2 Определения и обзор ПО**

# %% [markdown]
# Реляционные БД
# - Основной ресурс - таблица
# - Таблица скорее всего обозначает какую-то сущность

# %% [markdown]
# Таблица: Столбец Название и Тип Данных<br>
# Внутри одного столбца один тип данных</br>
# Между таблицами связи

# %% [markdown]
# Relate - относиться -> Реляционные БД -> Все таблицы взаимосвязаны по каким-то правилам

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
select 1

# %% [markdown]
# ![image.png](attachment:image.png)
